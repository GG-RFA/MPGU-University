# %% [markdown]
# Устанавливаем библиотеку для работы с ботом

# %%
# !pip3 install pytelegrambotapi
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.1/243.1 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pytelegrambotapi: filename=pyTelegramBotAPI-4.14.0-py3-none-any.whl size=215251 sha256=d4c64cda5931cbdc00baa3f10378a4613cb33caaa07fb04c04f4a90e44b734aa
#   Stored in directory: /root/.cache/pip/wheels/25/51/2d/24b40a366c85c37928d5aa36ddf257e5a79fad25e1ecd11b2c
# Successfully built pytelegrambotapi
# ...

# %% [markdown]
# Реализуем функционал бота

# %%
# Импортируем необходимую библиотеку
import telebot
# Задаём токен созданного бота в Telegram
bot = telebot.TeleBot('6766063953:AAG0WGrF2LngJucU9cNMHM_CIOAVD_r_Eo4')
# Создаём функцию, реализующую приветствие
@bot.message_handler(commands=['start'])
def say_hi(message):
    # Получаем имя пользователя из объекта message
    name = message.from_user.first_name
    # Отправляем приветственное сообщение с именем пользователя
    bot.send_message(message.chat.id, f'Привет, {name}!')
    # Отправляем стикер, id которого задаём
    bot.send_sticker(message.from_user.id, sticker='CAACAgIAAxkBAAEKj6FlMnECmeXXFr6_CX_-LkbP9U0aSgACtgADJQNSD87Rv7onHNCMMAQ')
# Запускаем бота
bot.polling()
